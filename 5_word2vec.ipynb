# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
# %matplotlib inline
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    #return tf.compat.as_str(f.read(name)).split()
    return f.read(name).encode('utf-8').split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# ('Most common words (+UNK)', [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)])
# ('Sample data', [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156])

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# ('data:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
#
# with num_skips = 2 and skip_window = 1:
# ('    batch:', ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term'])
# ('    labels:', ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a'])
#
# with num_skips = 4 and skip_window = 2:
# ('    batch:', ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a'])
# ('    labels:', ['anarchism', 'term', 'originated', 'a', 'of', 'as', 'term', 'originated'])

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.077399
# Nearest to it: eruptions, holstein, kattegat, babylonians, cabell, cyclists, sunrise, acetylcholine,
# Nearest to history: portray, leftmost, zariski, logitech, pavements, tailpiece, htm, liz,
# Nearest to but: inadvertently, guanine, citadel, interacts, vagus, federer, oscilloscope, mucous,
# Nearest to these: multivibrator, inv, claremont, insurgency, aspartic, seafloor, hadiths, catherine,
# Nearest to american: kirtland, generate, okinawa, volga, socialism, soma, practiced, nanosystems,
# Nearest to all: pimlico, centrum, nursia, surah, telomeres, anoint, kerouac, obi,
# Nearest to time: vocal, quantity, commonality, quakers, yeho, rind, likely, measurable,
# Nearest to be: caddy, acquisition, assailants, etext, joachim, normalize, stoics, unsteady,
# Nearest to other: envelopes, akademie, cameos, abaye, heinous, falun, duplication, morrissey,
# Nearest to than: lorenzo, ldapv, sza, counselors, delgado, zane, xie, singleton,
# Nearest to state: chou, materiality, spares, stealth, sightings, reused, inherently, pai,
# Nearest to this: hackers, verona, canines, syntax, mythic, beasts, birthplace, thriller,
# Nearest to zero: navin, cloister, bis, computational, fayyum, wessel, identifying, betsy,
# Nearest to five: geats, iconoclastic, israel, privatized, foreshadow, peptides, copts, chinook,
# Nearest to war: homage, krypton, reith, incitement, spoiling, hearers, chimneys, coco,
# Nearest to system: microorganisms, rgb, impending, robber, nader, disruptive, cession, resumption,
# Average loss at step 2000: 4.360343
# Average loss at step 4000: 3.863507
# Average loss at step 6000: 3.795160
# Average loss at step 8000: 3.686267
# Average loss at step 10000: 3.612853
# Nearest to it: he, this, which, there, we, they, that, also,
# Nearest to history: alb, htm, elaborate, portray, logitech, extolling, leftmost, rehearsing,
# Nearest to but: inadvertently, primes, followers, citadel, ocular, gandy, robotic, however,
# Nearest to these: aspartic, eventually, downgraded, reconsider, aznar, all, insurgency, rebuttals,
# Nearest to american: socialism, generate, kirtland, linguist, porridge, irregularly, trivially, british,
# Nearest to all: pimlico, hastened, entebbe, ahmed, because, these, telomeres, velarized,
# Nearest to time: year, quantity, sahelian, debacle, convenient, disaster, adjustable, vocal,
# Nearest to be: have, been, is, indicating, glues, was, qxd, jaws,
# Nearest to other: morrissey, duplication, bart, fante, mobilization, falun, rg, indefatigable,
# Nearest to than: delgado, counselors, lorenzo, sza, singleton, recharge, philemon, imax,
# Nearest to state: though, reused, retaliation, newest, wakko, use, rival, inherently,
# Nearest to this: it, which, the, that, a, dion, mythic, horrors,
# Nearest to zero: nine, eight, six, five, seven, three, four, two,
# Nearest to five: eight, six, nine, four, three, seven, zero, two,
# Nearest to war: reith, homage, incitement, krypton, coco, thickened, personality, capping,
# Nearest to system: microorganisms, cycles, shelling, letterbox, tarsus, impending, unconfirmed, indianapolis,
# Average loss at step 12000: 3.607300
# Average loss at step 14000: 3.576672
# Average loss at step 16000: 3.408103
# Average loss at step 18000: 3.456750
# Average loss at step 20000: 3.537392
# Nearest to it: he, this, there, which, they, we, she, not,
# Nearest to history: alb, portray, nonterminals, philosophy, flight, elaborate, htm, lass,
# Nearest to but: however, although, inadvertently, if, and, that, which, they,
# Nearest to these: some, many, such, all, several, which, downgraded, different,
# Nearest to american: british, australian, porridge, generate, yorkshire, english, national, kroon,
# Nearest to all: pimlico, these, many, feud, velarized, kes, anoint, junk,
# Nearest to time: year, disaster, adjustable, mittag, case, polos, summing, sahelian,
# Nearest to be: been, have, was, is, were, jaws, indicating, become,
# Nearest to other: many, fante, centimeters, some, indefatigable, affluent, beverly, mobilization,
# Nearest to than: or, delgado, messalina, singleton, counselors, intentions, imax, sza,
# Nearest to state: rival, retaliation, newest, inherently, general, truss, tsuba, ign,
# Nearest to this: it, which, the, its, participle, vista, dion, apa,
# Nearest to zero: five, six, four, eight, three, seven, nine, two,
# Nearest to five: six, eight, three, four, seven, zero, two, nine,
# Nearest to war: reith, homage, coco, incitement, interscope, indian, krypton, madman,
# Nearest to system: microorganisms, memphis, projects, amnon, deficits, cession, tarsus, cycles,
# Average loss at step 22000: 3.500814
# Average loss at step 24000: 3.488763
# Average loss at step 26000: 3.477035
# Average loss at step 28000: 3.477599
# Average loss at step 30000: 3.499086
# Nearest to it: he, this, there, she, they, which, also, we,
# Nearest to history: philosophy, portray, launch, alb, zariski, curtains, liz, holding,
# Nearest to but: however, although, where, when, if, inadvertently, which, though,
# Nearest to these: some, many, several, such, all, their, downgraded, they,
# Nearest to american: british, australian, german, italian, english, canadian, national, yorkshire,
# Nearest to all: some, these, remaining, many, discomfort, byrd, nanometres, pimlico,
# Nearest to time: year, adjustable, disaster, mittag, choice, rodan, summing, ptolemy,
# Nearest to be: been, have, is, were, digger, are, dismayed, was,
# Nearest to other: various, these, fante, some, different, their, are, indefatigable,
# Nearest to than: delgado, or, messalina, derailed, estimating, jonny, undertook, intentions,
# Nearest to state: inherently, retaliation, rival, tsuba, newest, negatives, law, grocer,
# Nearest to this: which, it, another, that, sheik, there, appreciation, processor,
# Nearest to zero: five, four, seven, three, eight, six, nine, two,
# Nearest to five: four, six, seven, three, eight, zero, two, nine,
# Nearest to war: reith, homage, interscope, coco, indian, schwarzschild, sha, romania,
# Nearest to system: systems, microorganisms, seaports, tupolev, robber, micro, memphis, germans,
# Average loss at step 32000: 3.502255
# Average loss at step 34000: 3.490503
# Average loss at step 36000: 3.453105
# Average loss at step 38000: 3.302314
# Average loss at step 40000: 3.433260
# Nearest to it: he, there, this, she, they, which, not, we,
# Nearest to history: philosophy, economy, peripherals, medieval, portray, richardson, flight, tab,
# Nearest to but: however, although, and, though, where, are, while, see,
# Nearest to these: many, some, several, both, different, such, those, they,
# Nearest to american: british, australian, german, italian, french, english, canadian, national,
# Nearest to all: both, any, these, watering, discomfort, forgave, byrd, many,
# Nearest to time: year, choice, adjustable, rodan, disaster, period, debacle, quarter,
# Nearest to be: been, have, being, were, was, are, by, is,
# Nearest to other: various, indefatigable, different, fante, their, relatives, drill, several,
# Nearest to than: or, delgado, keanu, derailed, jonny, messalina, islets, intentions,
# Nearest to state: rival, inherently, retaliation, law, newest, negatives, tsuba, grocer,
# Nearest to this: which, it, that, the, any, another, denison, each,
# Nearest to zero: five, seven, nine, six, eight, four, three, two,
# Nearest to five: seven, six, three, four, zero, eight, nine, two,
# Nearest to war: erika, interscope, reith, romania, sha, schwarzschild, bartos, syria,
# Nearest to system: systems, microorganisms, seaports, organiser, tupolev, euphrates, sicily, beos,
# Average loss at step 42000: 3.435638
# Average loss at step 44000: 3.449943
# Average loss at step 46000: 3.451306
# Average loss at step 48000: 3.356258
# Average loss at step 50000: 3.384662
# Nearest to it: he, she, there, this, they, now, cyanide, still,
# Nearest to history: medieval, peripherals, philosophy, zariski, economy, divina, disallow, precise,
# Nearest to but: however, although, while, though, when, and, which, stun,
# Nearest to these: some, many, several, both, such, those, different, are,
# Nearest to american: australian, british, english, italian, laban, french, german, russian,
# Nearest to all: each, course, both, aunts, biplane, many, tylor, some,
# Nearest to time: year, choice, period, disaster, thing, shorten, adjustable, rodan,
# Nearest to be: have, been, was, being, is, were, become, are,
# Nearest to other: various, different, many, some, hundred, these, indefatigable, mcclelland,
# Nearest to than: or, internetwork, derailed, keanu, undertook, intentions, khazar, slightly,
# Nearest to state: law, rival, retaliation, newest, inherently, negatives, tsuba, grocer,
# Nearest to this: which, it, the, another, overwhelmingly, apa, he, that,
# Nearest to zero: seven, eight, five, six, nine, three, four, two,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to war: interscope, erika, bartos, sha, reith, schwarzschild, syria, indian,
# Nearest to system: systems, seaports, microorganisms, organiser, tupolev, resumption, differentiating, sicily,
# Average loss at step 52000: 3.434298
# Average loss at step 54000: 3.428716
# Average loss at step 56000: 3.435264
# Average loss at step 58000: 3.397206
# Average loss at step 60000: 3.393472
# Nearest to it: he, she, there, this, we, which, they, that,
# Nearest to history: economy, medieval, philosophy, peripherals, list, demographics, demi, article,
# Nearest to but: however, although, and, though, see, than, hurd, while,
# Nearest to these: some, many, several, those, both, they, all, such,
# Nearest to american: australian, british, english, african, italian, german, french, european,
# Nearest to all: both, these, each, any, some, many, various, those,
# Nearest to time: year, choice, period, disaster, fiesta, way, debacle, quantity,
# Nearest to be: been, have, become, are, was, being, is, digger,
# Nearest to other: various, different, many, some, hundred, several, those, magnentius,
# Nearest to than: or, and, but, much, keanu, slightly, internetwork, messalina,
# Nearest to state: rival, law, retaliation, inherently, negatives, newest, tsuba, government,
# Nearest to this: it, which, there, that, facility, the, madhya, some,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to war: interscope, erika, bartos, reith, syria, lal, sha, wars,
# Nearest to system: systems, microorganisms, seaports, beos, puppies, organiser, sicily, modality,
# Average loss at step 62000: 3.238231
# Average loss at step 64000: 3.255050
# Average loss at step 66000: 3.401571
# Average loss at step 68000: 3.397404
# Average loss at step 70000: 3.356160
# Nearest to it: he, she, there, this, they, which, we, then,
# Nearest to history: list, medieval, philosophy, economy, peripherals, portray, journal, demographics,
# Nearest to but: however, although, though, which, while, that, than, really,
# Nearest to these: such, many, some, those, several, are, their, which,
# Nearest to american: australian, british, english, african, canadian, italian, german, gay,
# Nearest to all: some, many, any, both, various, every, each, discomfort,
# Nearest to time: period, choice, thing, disaster, year, skylab, way, galtieri,
# Nearest to be: been, is, have, were, being, are, become, by,
# Nearest to other: various, different, some, many, vegetal, several, hundred, feodor,
# Nearest to than: but, or, internetwork, while, much, keanu, slightly, haig,
# Nearest to state: rival, states, newest, republican, inherently, law, city, truss,
# Nearest to this: which, it, the, that, enigmatic, itself, another, there,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to five: six, four, eight, seven, zero, three, nine, two,
# Nearest to war: interscope, reith, wars, schwarzschild, erika, syria, indian, csc,
# Nearest to system: systems, method, beos, organiser, tupolev, cycles, worm, microorganisms,
# Average loss at step 72000: 3.374952
# Average loss at step 74000: 3.349839
# Average loss at step 76000: 3.316107
# Average loss at step 78000: 3.350043
# Average loss at step 80000: 3.375932
# Nearest to it: he, she, there, this, they, we, kuo, itself,
# Nearest to history: list, kuiper, medieval, demographics, peripherals, journal, university, economy,
# Nearest to but: however, although, than, while, though, which, really, unlike,
# Nearest to these: several, many, those, some, various, are, both, such,
# Nearest to american: british, australian, german, english, canadian, laban, italian, international,
# Nearest to all: both, each, many, some, any, various, every, these,
# Nearest to time: year, period, fiesta, skylab, reactants, threat, choice, disaster,
# Nearest to be: been, have, jaws, become, being, is, produce, was,
# Nearest to other: various, different, individual, western, many, vegetal, alkene, including,
# Nearest to than: or, but, while, much, diffused, internetwork, clinicians, khazar,
# Nearest to state: states, newest, rival, city, grocer, inherently, purposeful, republican,
# Nearest to this: which, it, itself, the, another, there, participle, what,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to war: wars, schwarzschild, interscope, csc, slaughtering, erika, reith, lal,
# Nearest to system: systems, cycles, seaports, abusive, beos, puppies, organiser, method,
# Average loss at step 82000: 3.409240
# Average loss at step 84000: 3.410066
# Average loss at step 86000: 3.390795
# Average loss at step 88000: 3.351715
# Average loss at step 90000: 3.362156
# Nearest to it: he, she, there, they, this, we, which, therefore,
# Nearest to history: list, economy, medieval, philosophy, demographics, kuiper, journal, leptons,
# Nearest to but: however, although, and, while, though, which, xun, they,
# Nearest to these: several, many, some, those, are, various, such, both,
# Nearest to american: british, australian, canadian, italian, french, african, german, english,
# Nearest to all: many, both, every, some, several, various, any, these,
# Nearest to time: period, year, day, thing, disaster, skylab, womanhood, galtieri,
# Nearest to be: been, become, was, have, being, is, receive, produce,
# Nearest to other: various, individual, pla, different, chapultepec, others, many, vegetal,
# Nearest to than: or, slightly, diffused, clinicians, legalize, khazar, internetwork, jozef,
# Nearest to state: states, city, government, rival, republican, newest, inherently, graceful,
# Nearest to this: it, which, another, the, itself, some, manipulative, serapis,
# Nearest to zero: five, seven, six, eight, nine, four, three, two,
# Nearest to five: eight, four, six, seven, three, nine, zero, two,
# Nearest to war: wars, schwarzschild, erika, interscope, csc, gospel, lal, fulfilment,
# Nearest to system: systems, cycles, method, process, beos, tupolev, model, puppies,
# Average loss at step 92000: 3.399254
# Average loss at step 94000: 3.253875
# Average loss at step 96000: 3.352752
# Average loss at step 98000: 3.248278
# Average loss at step 100000: 3.358924
# Nearest to it: he, she, this, there, they, never, which, what,
# Nearest to history: list, demographics, economy, nsh, mappings, philosophy, unreadable, science,
# Nearest to but: however, although, though, while, and, where, when, whereas,
# Nearest to these: several, many, some, those, various, all, which, both,
# Nearest to american: british, australian, english, canadian, italian, french, irish, german,
# Nearest to all: these, every, various, any, both, many, several, some,
# Nearest to time: year, period, length, skylab, thing, womanhood, lives, whittaker,
# Nearest to be: been, have, being, is, easily, become, are, thurgood,
# Nearest to other: various, others, individual, hundred, forgave, different, belle, including,
# Nearest to than: or, slightly, while, diffused, undertook, frictional, khazar, much,
# Nearest to state: states, city, thee, rival, islamism, government, inherently, pontiff,
# Nearest to this: which, it, another, itself, what, some, that, complicate,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to war: wars, interscope, erika, schwarzschild, bhakti, lal, fulfilment, ordeal,
# Nearest to system: systems, model, cycles, seaports, tupolev, representation, process, method,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, 2*skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    for i2 in range(2*skip_window):
        batch[i][i2] = buffer[i2] 
    target = skip_window  # target label at the center of the buffer
    batch[i][target] = buffer[span-1]
    labels[i, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print(batch)
    print(labels)
    #print('    batch:', [reverse_dictionary[bi] for bi in batch])
    #print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# ('data:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
#
# with num_skips = 2 and skip_window = 1:
# [[5239   12]
#  [3084    6]
#  [  12  195]
#  [   6    2]]
# [[3084]
#  [  12]
#  [   6]
#  [ 195]]
#
# with num_skips = 4 and skip_window = 2:
# [[5239 3084  195    6]
#  [3084   12    2  195]
#  [  12    6 3137    2]
#  [   6  195   46 3137]]
# [[ 12]
#  [  6]
#  [195]
#  [  2]]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window]) ##liu
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.Variable(tf.zeros([batch_size, embedding_size]))
  for i in range(2*skip_window):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
  embed = embed / (2*skip_window)
  #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.550236
# Nearest to with: daring, echidna, oss, strau, fein, properly, cc, evaluate,
# Nearest to five: unencumbered, holding, drummer, irritating, directv, vein, parlour, accompanying,
# Nearest to new: polymath, valois, secunda, palace, pcd, encephalopathy, nationalised, commercialize,
# Nearest to up: maligned, pattie, bandy, detachable, hooks, isabella, khans, checks,
# Nearest to but: heckel, sandpaper, picirilli, outflow, difficulties, technological, botched, arcades,
# Nearest to at: tia, retrieving, decolonisation, nigsberg, gregory, kindergarten, gender, amundsen,
# Nearest to he: bluescreen, stuck, jenna, groups, vans, veil, thousand, accounted,
# Nearest to not: solanaceae, amaterasu, roberto, paine, counterrevolutionary, texaco, reportedly, sash,
# Nearest to of: steinbeck, particularity, rhythm, cac, opportunity, vigorously, polymaths, substantive,
# Nearest to in: tea, shaken, bene, xaver, obscuring, satisfy, hard, expansionary,
# Nearest to if: planet, mcmahon, tutu, nearer, uniting, bow, sikhs, betrothed,
# Nearest to his: systematic, volunteers, horowitz, rosa, lawfully, vines, kd, seaway,
# Nearest to states: hacienda, priming, ola, alligators, fame, than, conspirators, foodstuffs,
# Nearest to most: franken, messe, humoral, mating, eleusis, alexius, davenport, facts,
# Nearest to between: belfast, disintegrated, austria, visually, mired, constant, kling, wingers,
# Nearest to were: programme, fulgencio, sisterhood, alves, kuwaiti, convincingly, autobiographies, density,
# Average loss at step 2000: 3.955010
# Average loss at step 4000: 3.432844
# Average loss at step 6000: 3.291152
# Average loss at step 8000: 3.151271
# Average loss at step 10000: 3.117102
# Nearest to with: exploit, in, heretic, bundesl, oss, musicality, akan, dci,
# Nearest to five: eight, nine, six, three, seven, four, zero, two,
# Nearest to new: polymath, palace, pathological, valois, islanders, ceo, estuary, odes,
# Nearest to up: bandy, infecting, detachable, critical, lived, fracturing, jeanne, maligned,
# Nearest to but: however, and, difficulties, enjoying, heckel, jacobsen, indebtedness, ecommerce,
# Nearest to at: in, deliberate, metamorphoses, tia, vivid, glottis, from, builder,
# Nearest to he: it, they, who, she, vector, abolishment, there, regius,
# Nearest to not: also, solanaceae, electrostatics, brief, longshanks, amounting, chlamydia, who,
# Nearest to of: in, for, during, ornamentation, euro, dexter, rewarded, regarding,
# Nearest to in: of, at, sagrada, on, between, with, alert, sprint,
# Nearest to if: fuji, where, tutu, mcmahon, uniting, teams, betrothed, peanuts,
# Nearest to his: their, her, its, magnate, the, holt, this, pinyin,
# Nearest to states: hacienda, smpte, alligators, priming, zyklon, emissions, warehouses, bombardier,
# Nearest to most: franken, humoral, messe, facts, loren, drastic, kvass, obsession,
# Nearest to between: into, kling, belfast, in, against, throughout, visually, constant,
# Nearest to were: are, was, have, sisterhood, comstock, slipping, had, foregoing,
# Average loss at step 12000: 3.143627
# Average loss at step 14000: 3.102114
# Average loss at step 16000: 3.130293
# Average loss at step 18000: 3.080856
# Average loss at step 20000: 2.971898
# Nearest to with: between, exploit, indulged, heretic, lobbyist, amplifier, affonso, northerly,
# Nearest to five: eight, four, six, seven, three, nine, zero, two,
# Nearest to new: pathological, valois, husk, palace, reinstating, amassed, interesting, polymath,
# Nearest to up: him, out, them, infecting, fracturing, bandy, jeanne, flattening,
# Nearest to but: however, and, although, though, see, ecommerce, disobey, smelting,
# Nearest to at: in, metamorphoses, vivid, during, farming, identifiable, builder, clique,
# Nearest to he: she, it, they, who, there, phenomenological, abolishment, fremantle,
# Nearest to not: solanaceae, electrostatics, often, amounting, chlamydia, also, longshanks, they,
# Nearest to of: regarding, deadites, fbi, laika, in, stepmother, ornamentation, for,
# Nearest to in: at, during, until, abet, through, between, sagrada, throughout,
# Nearest to if: where, tutu, fuji, uniting, charm, when, maududi, does,
# Nearest to his: their, her, its, the, holt, s, magnate, purchasing,
# Nearest to states: priming, smpte, alligators, hacienda, tendon, zyklon, issuing, bombardier,
# Nearest to most: more, many, some, humoral, emirs, aml, possession, drastic,
# Nearest to between: with, into, against, kling, throughout, belfast, in, during,
# Nearest to were: are, have, was, been, be, slipping, commentaries, comstock,
# Average loss at step 22000: 3.040525
# Average loss at step 24000: 3.010360
# Average loss at step 26000: 2.984605
# Average loss at step 28000: 3.007013
# Average loss at step 30000: 2.979222
# Nearest to with: between, in, dci, affonso, northerly, sussex, tetum, against,
# Nearest to five: four, six, three, seven, eight, nine, two, zero,
# Nearest to new: pathological, ethical, valois, barracks, husk, bazin, reinstating, groupings,
# Nearest to up: out, him, them, off, flattening, back, ivo, waltzes,
# Nearest to but: however, and, although, see, though, ecommerce, amphisbaena, smelting,
# Nearest to at: in, metamorphoses, during, farming, throughout, within, clique, builder,
# Nearest to he: she, it, they, who, there, we, originally, abolishment,
# Nearest to not: chlamydia, always, still, almost, now, usually, never, electrostatics,
# Nearest to of: in, regarding, including, deadites, laika, for, hammerhead, same,
# Nearest to in: during, within, of, on, at, until, between, among,
# Nearest to if: where, when, does, tutu, charm, fuji, peanuts, might,
# Nearest to his: their, her, its, your, the, my, holt, our,
# Nearest to states: nations, alligators, priming, weyl, tendon, smpte, metaphors, consumers,
# Nearest to most: more, many, some, possession, emirs, wordsworth, drastic, aml,
# Nearest to between: with, against, kling, into, in, during, among, belfast,
# Nearest to were: are, have, was, been, had, be, comstock, zeppo,
# Average loss at step 32000: 2.828949
# Average loss at step 34000: 2.942403
# Average loss at step 36000: 2.928178
# Average loss at step 38000: 2.933621
# Average loss at step 40000: 2.908023
# Nearest to with: between, exploit, against, affonso, in, northerly, when, using,
# Nearest to five: six, seven, four, three, eight, nine, two, zero,
# Nearest to new: pathological, ethical, valois, barracks, husk, groupings, bazin, lucca,
# Nearest to up: him, out, them, off, together, flattening, back, butcher,
# Nearest to but: however, and, although, while, though, which, see, yet,
# Nearest to at: in, during, metamorphoses, after, throughout, within, before, suffix,
# Nearest to he: she, it, they, who, there, we, finally, abolishment,
# Nearest to not: always, never, almost, usually, chlamydia, still, now, longshanks,
# Nearest to of: regarding, including, deadites, same, krahn, hammerhead, for, stepmother,
# Nearest to in: during, within, throughout, at, on, from, through, tod,
# Nearest to if: when, where, before, charm, octopussy, does, until, then,
# Nearest to his: her, their, its, your, my, the, our, holt,
# Nearest to states: nations, kingdom, priming, metaphors, france, weyl, consumers, tendon,
# Nearest to most: more, some, many, emirs, possession, both, best, sonny,
# Nearest to between: with, among, throughout, kling, around, into, against, within,
# Nearest to were: are, have, was, been, had, be, those, including,
# Average loss at step 42000: 2.938659
# Average loss at step 44000: 2.942381
# Average loss at step 46000: 2.904505
# Average loss at step 48000: 2.864636
# Average loss at step 50000: 2.842216
# Nearest to with: between, using, affonso, in, when, indulged, northerly, lacaille,
# Nearest to five: four, seven, three, six, eight, nine, two, zero,
# Nearest to new: ethical, pathological, groupings, bazin, barracks, lucca, estrada, husk,
# Nearest to up: out, him, off, them, together, back, down, flattening,
# Nearest to but: however, although, though, while, and, or, which, yet,
# Nearest to at: in, during, metamorphoses, on, after, builder, throughout, from,
# Nearest to he: she, it, they, who, there, we, originally, never,
# Nearest to not: always, never, almost, still, usually, they, chlamydia, now,
# Nearest to of: in, including, laika, regarding, during, deadites, gives, ornamentation,
# Nearest to in: during, within, at, throughout, of, until, on, from,
# Nearest to if: when, where, before, though, because, rik, for, until,
# Nearest to his: her, their, your, its, our, my, the, holt,
# Nearest to states: nations, metaphors, kingdom, tendon, priming, consumers, issuing, drying,
# Nearest to most: more, some, many, possession, emirs, less, wordsworth, best,
# Nearest to between: with, among, against, throughout, within, into, during, around,
# Nearest to were: are, have, had, been, was, be, those, including,
# Average loss at step 52000: 2.882549
# Average loss at step 54000: 2.861295
# Average loss at step 56000: 2.858075
# Average loss at step 58000: 2.760055
# Average loss at step 60000: 2.826015
# Nearest to with: between, when, northerly, icrm, indulged, while, using, against,
# Nearest to five: seven, four, six, three, eight, nine, zero, two,
# Nearest to new: pathological, groupings, specific, valois, bazin, barracks, ethical, different,
# Nearest to up: out, off, him, them, together, down, back, flattening,
# Nearest to but: however, and, although, though, which, while, during, see,
# Nearest to at: in, during, on, throughout, metamorphoses, builder, geocache, near,
# Nearest to he: she, it, they, who, there, we, eventually, i,
# Nearest to not: always, never, still, almost, usually, now, actually, electrostatics,
# Nearest to of: including, regarding, laika, deadites, in, ornamentation, stepmother, although,
# Nearest to in: during, within, at, throughout, on, until, among, through,
# Nearest to if: when, where, before, then, though, until, because, rik,
# Nearest to his: her, their, your, my, its, our, the, holt,
# Nearest to states: nations, kingdom, metaphors, consumers, tendon, overrun, priming, weyl,
# Nearest to most: more, some, many, emirs, possession, less, wordsworth, best,
# Nearest to between: with, among, within, into, throughout, against, during, around,
# Nearest to were: are, have, was, had, been, including, those, be,
# Average loss at step 62000: 2.830744
# Average loss at step 64000: 2.777275
# Average loss at step 66000: 2.769204
# Average loss at step 68000: 2.720038
# Average loss at step 70000: 2.770535
# Nearest to with: between, when, northerly, during, among, plenipotentiary, in, icrm,
# Nearest to five: seven, six, four, three, eight, nine, two, zero,
# Nearest to new: pathological, specific, bazin, groupings, barracks, ethical, telstar, lucca,
# Nearest to up: off, out, him, down, together, them, back, flattening,
# Nearest to but: however, although, though, and, while, which, calmly, during,
# Nearest to at: during, in, on, near, throughout, under, before, metamorphoses,
# Nearest to he: she, it, they, who, there, we, eventually, never,
# Nearest to not: always, never, still, now, almost, electrostatics, normally, usually,
# Nearest to of: including, in, regarding, laika, hermon, concerning, ornamentation, deadites,
# Nearest to in: during, within, throughout, on, under, until, at, since,
# Nearest to if: when, where, before, until, though, since, because, rik,
# Nearest to his: her, their, your, its, my, our, whose, the,
# Nearest to states: nations, kingdom, consumers, metaphors, hacienda, drying, priming, weyl,
# Nearest to most: more, many, some, less, possession, emirs, especially, wordsworth,
# Nearest to between: with, among, within, against, during, throughout, into, around,
# Nearest to were: are, was, have, had, those, been, be, including,
# Average loss at step 72000: 2.808443
# Average loss at step 74000: 2.657458
# Average loss at step 76000: 2.803102
# Average loss at step 78000: 2.825865
# Average loss at step 80000: 2.787540
# Nearest to with: between, when, northerly, using, affonso, in, plus, by,
# Nearest to five: seven, six, four, eight, three, nine, two, zero,
# Nearest to new: pathological, specific, bazin, barracks, valois, groupings, estrada, andhra,
# Nearest to up: off, out, down, back, him, together, them, flattening,
# Nearest to but: however, although, though, and, which, see, while, or,
# Nearest to at: during, in, throughout, near, under, within, geocache, on,
# Nearest to he: she, it, they, who, there, we, finally, never,
# Nearest to not: still, never, almost, always, normally, discretionary, actually, electrostatics,
# Nearest to of: including, in, regarding, and, laika, although, concerning, hermon,
# Nearest to in: during, within, throughout, at, on, under, until, of,
# Nearest to if: when, where, though, since, before, then, because, rik,
# Nearest to his: her, their, your, my, its, our, holt, whose,
# Nearest to states: nations, kingdom, state, metaphors, consumers, weyl, drying, priming,
# Nearest to most: many, some, more, less, both, possession, emirs, all,
# Nearest to between: among, with, within, throughout, during, against, microbats, into,
# Nearest to were: are, was, have, had, been, those, be, including,
# Average loss at step 82000: 2.679896
# Average loss at step 84000: 2.778477
# Average loss at step 86000: 2.742482
# Average loss at step 88000: 2.759852
# Average loss at step 90000: 2.745290
# Nearest to with: between, among, northerly, exploit, indulged, icrm, using, in,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to new: pathological, groupings, specific, bazin, barracks, veterinary, estrada, husk,
# Nearest to up: off, out, down, back, together, him, them, flattening,
# Nearest to but: however, although, though, see, and, while, ecommerce, which,
# Nearest to at: during, in, near, throughout, under, currently, before, within,
# Nearest to he: she, it, they, who, there, we, never, subsequently,
# Nearest to not: never, always, almost, still, actually, therefore, now, normally,
# Nearest to of: regarding, including, concerning, in, for, melon, laika, involving,
# Nearest to in: during, within, on, throughout, at, near, until, around,
# Nearest to if: when, where, though, before, until, although, since, because,
# Nearest to his: her, their, your, my, our, its, whose, the,
# Nearest to states: nations, kingdom, state, metaphors, consumers, zyklon, drying, tendon,
# Nearest to most: more, many, some, less, both, especially, emirs, possession,
# Nearest to between: among, with, within, against, throughout, microbats, during, through,
# Nearest to were: are, have, those, was, had, been, include, including,
# Average loss at step 92000: 2.693000
# Average loss at step 94000: 2.729063
# Average loss at step 96000: 2.717323
# Average loss at step 98000: 2.381334
# Average loss at step 100000: 2.422901
# Nearest to with: between, by, in, among, during, when, plus, affonso,
# Nearest to five: seven, six, four, three, eight, nine, zero, two,
# Nearest to new: pathological, bazin, andhra, valois, husk, groupings, specific, veterinary,
# Nearest to up: off, out, down, together, back, him, them, flattening,
# Nearest to but: however, although, though, and, while, see, calmly, torso,
# Nearest to at: during, in, near, throughout, on, geocache, after, builder,
# Nearest to he: she, they, it, there, who, we, never, subsequently,
# Nearest to not: always, never, almost, actually, therefore, still, really, automatically,
# Nearest to of: concerning, regarding, in, laika, including, despite, deadites, pesticide,
# Nearest to in: during, at, within, near, throughout, on, among, despite,
# Nearest to if: when, before, though, where, after, until, since, then,
# Nearest to his: her, their, your, its, my, our, the, whose,
# Nearest to states: nations, kingdom, state, metaphors, consumers, drying, tendon, us,
# Nearest to most: more, some, many, less, especially, particularly, possession, highly,
# Nearest to between: among, with, within, against, microbats, throughout, belfast, attacker,
# Nearest to were: are, was, have, had, those, be, been, include,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
